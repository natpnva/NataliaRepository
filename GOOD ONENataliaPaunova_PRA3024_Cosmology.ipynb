# %% [markdown]
# # <font color='deepskyblue'>Cosmology MCMC notebook </font>

# %% [markdown]
# ## <font color='deepskyblue'>Preliminaries</font>

# %%
# Install required packages (if not available on server)
# %pip install getdist

# Load a bunch of packages (honetsly I took this from someone else and just assumed it would be everything I would ever need so I put it here)
import numpy as np
import matplotlib.pyplot as plt
import pylab
import getdist, IPython
from numpy import random
from IPython.display import Image
from getdist import plots, MCSamples, loadMCSamples
import astropy
from astropy import units as u
import pandas as pd
import math 
import scipy.integrate as integrate
from astropy import cosmology
import scipy
import sympy
from sympy import Integral

# %% [markdown]
# ## <span style='color:deepskyblue'> The $\Lambda$CDM Model </span>
#
# The Lambda-Cold-Dark-Matter ($\Lambda$CDM) Model is our concordance cosmological model. It postulates a Universe that behaves according to **General Relativity**, filled with **baryons** (protons, neutrons - the stuff we and stars are made of!), **Cold Dark Matter (CDM)** and a **Cosmological Constant** $\Lambda$.
#
# The expansion of the Universe is best described in terms of the **scale factor** $a$ (the "radius" of the Universe, conventionally set to 1 today) and the **Hubble rate** $H$
#
# $$
# H \equiv \frac{\dot a}{a}
# $$
#
# The Einstein Equations in a **homogeneous, isotropic** Universe have an especially simple form and a special name, **Friedmann Equation**:
#
# $$
# H^2 = \frac{8\pi G}{3}\rho + \frac{k}{a^2}
# $$
#
# where $\rho$ is the total energy density of the Universe (at a certain time or size), and $k$ is a universal constant related to the [spatial curvature and shape of the Universe](https://en.wikipedia.org/wiki/Shape_of_the_universe#:~:text=The%20spatial%20curvature%20is%20related,indistinguishable%20spaces%20with%20different%20topologies.). In the $\Lambda$CDM model, this additionally simplifies to
#
# $$
# \boxed{
# H^2 = H_0^2\left(\Omega_\Lambda + \Omega_m a^{-3} + \Omega_k a^{-2}\right)
# }
# \qquad
# \qquad
# \Omega_m + \Omega_\Lambda + \Omega_k = 1
# $$
#
# $H_0$ is the value of the Hubble rate *today*, and the parameters $\Omega_m$, $\Omega_\Lambda$ and $\Omega_k$ are dimensionless quantities indicating how much of the present expansion of the Universe is due to (non-relativistic) matter, cosmological constant $\Lambda$, and spatial curvature $k$. Note that the three $\Omega$'s are *not independent* (their sum is 1) and that we grouped together the contribution of baryons and CDM,
#
# $$
# \Omega_m = \Omega_{\rm CDM} + \Omega_{\rm b}
# $$
#
# and that we have evidence that independent evidence that $\Omega_b \approx 5$\%. Note that only $\Omega_m \geq 0$ makes physical sense, while in principle both $\Omega_\Lambda$ and $\Omega_k$ can be negative.
#
# The present Hubble rate is conventionally parametrised in terms of the dimensionless $h$:
#
# $$
# H_0 \equiv h\,\frac{100 \text{km}}{\text{s Mpc}}
# $$
#
# where Mpc = Megaparsec and [parsec](https://en.wikipedia.org/wiki/Parsec) equals to about $3.26$ light years or $3.086 \cdot 10^{16}$ m.
#
# In essence, these equations give us the relation between *what exists in the Universe* and *how the Universe expanded*. Measure one, I can tell you the other. This is precisely what we aim to do!
#
# Time to define the function $H(z)$. Don't forget to include the useful parameters as arguments of the function, and to define `parsec`.

# %%
H_0 = lambda h: h*100 # Hubble rate H_0(h) in km/s/Mpc
c = astropy.constants.c.value *1e-3 # Speed of light in km/s, I stole this from someone on the internet

# %% [markdown]
# Using $\Omega_k = 1-\Omega_\Lambda-\Omega_m $ and $a=(1+z)^{-1}$ we find:
# \begin{equation}
# H(z)=H_0(h)*\sqrt{\Omega_\Lambda+\left(1-\Omega_\Lambda-\Omega_m\right)\left(1+z\right)^2+\Omega_m\left(1+z\right)^3}
# \end{equation}

# %%
PARSEC = 3.086 * 10**16 #m

def H(z, h, OmegaM, OmegaL): # Hubble rate H(z) in km/s/Mpc
    H = H_0(h) * math.sqrt(OmegaL + (1 - OmegaL - OmegaM) * (z+1)**2 + OmegaM * (z+1)**3)
    return H

def integrateH(z, h, OmegaM, OmegaL):
    res = integrate.quad(lambda x: H(x, h, OmegaM, OmegaL), 0, z)
    return res[0]

# %%
# Just assuming some values
h = 0.7
z = 0.2
OmegaM = 0.34 # Density parameter for non-relativistic matter
OmegaL = 0.65 # Density parameter for lambda

# Redshift range
z_values = np.linspace(0, 2, 100)  # Redshift from 0 to 3
H_values = [H(z, h, OmegaM, OmegaL) for z in z_values]  # Calculate H(z) for each z

# Plotting, helped by Duck.ai
plt.figure(figsize=(10, 6))
plt.plot(z_values, H_values, label='Hubble Rate H(z)', color='pink')
plt.title('Hubble Rate H(z) vs Redshift z')
plt.xlabel('Redshift z')
plt.ylabel('Hubble Rate H(z) [km/s/Mpc]')
plt.axhline(y=H_0(h), color='red', linestyle='--', label='H_0 (Present Hubble Rate)')
plt.legend()
plt.grid()
plt.ylim(60, 225)  # Adjust y-axis limits for better visibility
plt.show()

# %% [markdown]
# ##  <span style='color:deepskyblue'>Supernovae Ia</span>
#
# In order to track the expansion of the Universe, we will look at Supernovae type Ia observations. SNIa are formed when a *white dwarf* accretes matter from a companion until it reaches a critical mass of about $1.44 M_\odot$ (solar masses), after which it explodes **at always the same luminosity** $L_{\rm SN}$. Therefore, the observed [magnitude](https://en.wikipedia.org/wiki/Magnitude_(astronomy)) is only a function of their [**luminosity distance**](https://en.wikipedia.org/wiki/Distance_measures_(cosmology)) from Earth, defined as the ratio of the intrinsic luminosity $L_{\rm SNIa}$ and the measured *surface brightness* $\Phi$ (energy per unit time per unit area)
#
# $$ d_L\equiv \frac{L_{\rm SN}}{4\pi \Phi} $$
#
# While photons (light rays) travel from the distant SNIa to Earth, the Universe expands and the photons get redshifted, and this redshift is directly related to the size of the Universe when the photon was emitted compared to today:
#
# $$ \frac{\lambda_{\rm obs}}{\lambda_{\rm em}} \equiv 1 + z_{\rm em} = \frac{1}{a_{\rm em}}$$
#
# We can express the luminosity distance in terms of the Hubble rate:
#
# $$
# \boxed{
# d_L(z) = \frac{c}{H_0}(1+z) \times
# \begin{cases}
#     \cfrac{1}{\sqrt{\Omega_k}} \sinh\left(\sqrt{\Omega_k}D(z)\right) & \Omega_k > 0
#     \\[.5em]
#     D(z) & \Omega_k = 0
#     \\[.5em]
#     \cfrac{1}{\sqrt{-\Omega_k}} \sin\left(\sqrt{-\Omega_k}D(z)\right) & \Omega_k < 0
# \end{cases}
# \qquad\qquad
# D(z) \equiv H_0\int_0^z \frac{{\rm d}Z}{H(Z)}
# }
# $$
#
# where $c$ is the speed of light: $c \simeq 2.998 \cdot 10^{5}$ km/s.
#
# Clearly, there exists a relation between $d_L(z)$ and $H(z)$, so the luminosity distance is a useful measure of the Universe expansion history.
#
# We can create the function `dL(z, h, Omega_m, Omega_L)`. You can also pass the function `Hubble` as an argument: `dL(z, Hubble, Omega_m, Omega_Lambda)`. Additionally, you can create $D(z)$ for your convenience.
#
# Note that you need to integrate the function $H(z)$, so write your own quick-and-easy numerical integrator or [look up the pre-written methods](https://docs.scipy.org/doc/scipy/reference/tutorial/integrate.html). Make sure it returns $d_L$ in parsecs and that it uses $H_0$ measured in km/s/Mpc!

# %%
# c is already defined above

# Comoving distance
def Dz(z, h, OmegaM, OmegaL): 
    # using the integral of H(z) from 0 to z with the help of scipy.integrate.quad
    res = integrate.quad(lambda x: (H_0(h) / H(x, h, OmegaM, OmegaL)), 0, z)
    # the integral returns a tuple with the result and the error of which we only need the result
    return res[0]

# Luminosity distance
def dL(z,h,OmegaM,OmegaL): 
    # as mentioned above OmegaK = 1 - OmegaL - OmegaM
    OmegaK = 1 - OmegaL - OmegaM
    # using the comoving distance Dz(z) to calculate the luminosity distance
    d_z = Dz(z, h, OmegaM, OmegaL)
    # defining the cases where OmegaK is positive, zero or negative
    if OmegaK > 0:
        dl = 1 / math.sqrt(OmegaK) * math.sinh(math.sqrt(OmegaK) * d_z)
    elif OmegaK == 0:
        dl = d_z
    elif OmegaK < 0:
        dl = 1 / math.sqrt(-OmegaK) * math.sin(math.sqrt(-OmegaK) * d_z)
    # returning the luminosity distance in Mpc
    return c * (1+z) * dl / H_0(h) 

# I used ai for the plotting again

# Redshift range
z_values = np.linspace(0, 2, 100)  # Redshift from 0 to 3
dL_values = [dL(z, h, OmegaM, OmegaL) for z in z_values]  # Calculate dL(z) for each z

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(z_values, dL_values, label='Luminosity Distance dL(z)', color='pink')
plt.title('Luminosity Distance dL(z) vs Redshift z')
plt.xlabel('Redshift z')
plt.ylabel('Luminosity Distance dL(z) [Mpc]')
plt.grid()
plt.legend()
plt.ylim(0, 14000)  # Adjust y-axis limits for better visibility
plt.show()

# Theoretical distance modulus
def mu(z, h, OmegaM, OmegaL): 
    # using the luminosity distance dL(z) to calculate the distance modulus
    dl = dL(z, h, OmegaM, OmegaL) 
    if dl <= 0:
        return float('nan')  # Return NaN if luminosity distance is non-positive
    # returning the distance modulus, converting dl from Mpc to pc
    return 5 * math.log10(dl * 1e6 / 10)

# Redshift range
z_values = np.linspace(0, 2, 100)  # Redshift from 0 to 3
mu_values = [mu(z, h, OmegaM, OmegaL) for z in z_values]  # Calculate mu(z) for each z

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(z_values, mu_values, label='Distance Modulus μ(z)', color='pink')
plt.title('Distance Modulus μ(z) vs Redshift z')
plt.xlabel('Redshift z')
plt.ylabel('Distance Modulus μ(z)')
plt.grid()
plt.legend()
plt.ylim(34, 48)  # Adjust y-axis limits for better visibility
plt.show()

# %% [markdown]
# ## <span style='color:deepskyblue'>The Union2.1 Compilation</span>
#
# Our source of data is from [Union2.1](http://supernova.lbl.gov/Union/). It is a collection of $580$ SNIa, each observation is comprised of redshift $z$ and [distance modulus](https://en.wikipedia.org/wiki/Distance_modulus) $\mu$ (and corresponding errors $\delta\mu$), defined as the difference between the *apparent magnitude* $m$ and the *absolute magnitude* $M$:
#
# $$
# \boxed{
# \mu(z) \equiv m(z) - M \equiv 5 \log_{10} \frac{d_L(z)}{10\,\text{pc}}
# }
# $$
#
# Our goal today is to use SNIa measurements to constrain the parameters ($h, \Omega_\Lambda, \Omega_m$).
#
# In essence, we can calculate for each redshift the theoretical value of $\mu$ using this equation with the expression for $d_L(z)$ and our model of choice $H(z)$ -- note that we will need to perform a numerical integral! -- and compare this value with observations. A different model would amount to changing the theoretical value of $H(z)$.
#
# Let us start by importing and plotting the data:

# %%
dataloc = "http://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt"

# Read in data as numpy array.
# Format is [name, redshift, magnitude, magnitude error, and another number?]
data = np.genfromtxt(dataloc)
# Print the first line as an example. (Note that genfromtxt turns the names into 'Not A Number')
print(data[0])
# Out:
# [           nan 2.84880000e-02 3.53465834e+01 2.23905933e-01
#  1.28418942e-01]

# %%
# Extract the redshifts (zs), distance modulus (dist_mod) and magnitude estimated errors (err_dist_mod)
zs = data.T[1] # redshift
dist_mod = data.T[2] # distance modulus
err_dist_mod = data.T[3] # errors on distance modulus = sigmas

# %%
# Let's look at the data, just for fun. 
# We can look both at the raw data (distance modulus) or calculate the luminosity distance
# Note that Numpy allows us to manipulate whole arrays at once
import scipy.integrate as integrate

# luminosity distance in pc
dpc = 10. * 10.**(dist_mod / 5.)

# and in Mpc
dMpc = dpc / 10.**6

# and the error on that distance:
dMe = 10. * (10.**((dist_mod + err_dist_mod)/5.-6.) - 10.**((dist_mod - err_dist_mod)/5.-6.))

# %%
# store the data in a pandas dataframe for easier manipulation
dataframe = pd.DataFrame({"redshift":zs, 
                   "distance_modulus":dist_mod,
                   "distance_modulus_error":err_dist_mod, 
                   "Luminosity distance pc":dpc,
                   "luminosity_distance_Mpc":dMpc ,
                   "error_luminosity_distance_Mpc":dMe})
dataframe.describe()
# Out:
#          redshift  distance_modulus  distance_modulus_error  \
# count  580.000000        580.000000              580.000000
# mean     0.361631         40.028495                0.222955
# std      0.327353          3.195595                0.126012
# min      0.015000         33.824609                0.084144
# 25%      0.054550         36.920249                0.151396
# 50%      0.294028         40.884198                0.189029
# 75%      0.551700         42.517637                0.241556
# max      1.414000         45.410744                1.006812
#
#        Luminosity distance pc  luminosity_distance_Mpc  \
# count            5.800000e+02               580.000000
# mean             2.209307e+09              2209.306847
# std              2.317339e+09              2317.338603
# min              5.819984e+07                58.199838
# 25%              2.422198e+08               242.219796
# 50%              1.502674e+09              1502.674447
# 75%              3.188077e+09              3188.076719
# max              1.208228e+10             12082.277932
#
#        error_luminosity_distance_Mpc
# count                     580.000000
# mean                      578.672983
# std                       882.688022
# min                         8.415859
# 25%                        33.323077
# 50%                       241.058999
# 75%                       796.924410
# max                      7101.793911

# %%
# sorting the red shift values in ascending order for better visualization later on
dataframe.sort_values(by=['redshift'], inplace=True)

# %%
plt.subplots(1, 2, figsize=(15, 5))

# Plot distance modulus versus redshift (original data)
plt.subplot(1, 2, 1)
plt.xlabel("Redshift")
plt.ylabel("Distance Modulus")
plt.errorbar(dataframe['redshift'], 
             dataframe['distance_modulus'], 
             yerr=dataframe["distance_modulus_error"], 
             fmt='o', 
             color='black', 
             ecolor='darkcyan', 
             markersize=4)

# Plot luminosity distance versus redshift
plt.subplot(1, 2, 2)
plt.xlabel("Redshift")
plt.ylabel("Luminosity Distance [Mpc]")
plt.errorbar(dataframe['redshift'], 
             dataframe['luminosity_distance_Mpc'], 
             yerr=dataframe['error_luminosity_distance_Mpc'], 
             fmt='o', 
             color='black', 
             ecolor='darkcyan', 
             markersize=4)
plt.show()

# %% [markdown]
# ## <span style='color:deepskyblue'>Bayes' Theorem: Likelihood, Prior, Posterior (and Evidence...)</span>
#
# The **conditional probability of A given that B is true** is denoted with $P(A|B)$ (read: *probability of A given B*).
# Did A happen? Then B has probability $P(B|A)$ of happening.
#
# [**Bayes' Theorem**](https://en.wikipedia.org/wiki/Bayes%27_theorem) is simply a reflection of the symmetry of the concept of joint probability:
#
# $$
# P(A|B)P(B) = P(B|A)P(A)
# $$
#
# In physics, our goal is often to determine how likely the values of some parameters $\theta$ are, given how well they reproduce the data $D$.
# We write Bayes' theorem in the following equivalent form:
#
# $$
# P(\theta | D) = \frac{P(D|\theta)P(\theta)}{P(D)}
# $$
#
# The various terms conventionally take the names:
#
# $$
# \begin{aligned}
# P(\theta | D) & && \text{Posterior}
# \\
# P(D | \theta)& && \text{Likelihood}
# \\
# P(\theta) & && \text{Prior}
# \\
# P(D) & && \text{Evidence}
# \end{aligned}
# $$
#
# ### <span style='color:deepskyblue'>Prior</span>
#
# The *prior* quantifies our degree of prior belief in the model parameters. It can contain the results of previous experiments, or theoretical considerations (for instance, that certain parameters cannot be negative, etc.).
#
# We can have *strong priors* about something - the Sun still existing at night, see the comic below - or not.
# When we do *not* have compelling prior knowledge about a parameter, we generally use a *non-informative* prior probability distribution, most often related to the [uniform distribution](https://en.wikipedia.org/wiki/Continuous_uniform_distribution)
#
# $$
# \begin{aligned}
#     \text{Uniform} & && \theta \in \text{Uniform}[\theta_{\rm min}, \theta_{\rm max}]
#     \\
#     \text{Log Uniform} & && \log\theta \in \text{Uniform}[\log\theta_{\rm min}, \log\theta_{\rm max}]
# \end{aligned}
# $$
#
# You may sometimes hear that "the prior doesn't matter". While this is not strictly true, it is however true that in many instances the *likelihood* depends more dramatically on the parameters and will have a dominating contribution to the posterior. You are more than welcome to try different priors for the model parameters and see if and how your results change.
#
# ### <span style='color:deepskyblue'>Likelihood</span>
#
# The measure of how well our model reproduces the data is the **likelihood** $\mathcal L$. For normal (=Gaussian), uncorrelated data $\mu_i$ with errors $\sigma_i$ ($i = \{1,580\}$), the likelihood is related to the famous [**chi-squared**](https://en.wikipedia.org/wiki/Chi-square_distribution) via
#
# $$
# P(D | \theta) \equiv \mathcal L = \exp\left(-\frac{\chi^2}{2}\right)
# \qquad
# \qquad
# \boxed{
# \chi^2 \equiv \sum_{i=1}^{580} \frac{\left(\mu_i^{(\rm theor)} - \mu_i^{(\rm obs)}\right)^2}{\sigma_i^2}
# }
# $$
#
# A *high likelihood* corresponds to a *low chi squared*.
#
# In principle, we could attack the problem brute-force: create a grid of values for $h$, $\Omega_m$, $\Omega_\Lambda$, calculate the likelihood for each combination, and create a profile for the likelihood.
#
# In practical cases, however, this is not only sub-optimal but sometimes **impossible**. Think of complicated models with 20+ free parameters (this is not that unusual in physics, by the way). Even a very coarse grained grid of 100 values for each parameter would result in more than$10^{40}$ (!!!) different parameter combination to be tested. You can probably understand why this is undesirable.
#
# ### <span style='color:deepskyblue'>Evidence</span>
#
# This is the tricky bit. The evidence, which is "*the probability of observing certain data*", is not something that is easy to evaluate or interpret. This looks like a serious limitation to finding the:
#
#
# ### <span style='color:deepskyblue'>Posterior</span>
#
# What does the data tell us about the model parameters? The answer is the *posterior probability distribution*, often (but not necessarily) expressed as (average $\pm$ standard deviation)
#
# $$
# \theta_i = \bar\theta_i \pm \sigma_i
# $$
#
# In other words, the posterior tells us how likely it is for the model parameters to have certain values, *given that we observe the data* $D$.
#
# *This is the final goal of our analysis!*
#
# <br>
#
# ![title](http://1.bp.blogspot.com/-tTx4HDejSww/ULcTeK9_V_I/AAAAAAAAA8g/PCYOH-eXGbk/s1600/frequentists_vs_bayesians.png)
# ![title](https://i.redd.it/5r0hwixt0m931.jpg)

# %% [markdown]
# ## <span style='color:deepskyblue'>Markov-Chain Monte Carlo</span>
#
# Markov-Chain Monte Carlo techniques are a class of methods to sample a probability distribution $P(x)$ - in our case $P(\theta | D)$ - provided that we can calculate a density $\mathcal F(x)$ **that is proportional to it** - in our case $P(\theta)P(D|\theta)$ = likelihood $\times$ prior. Among these, a very popular one is the [**Metropolis-Hastings**](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) algorithm, which is what we will use.
#
# Schematically, the algorithm works as follows:
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and calculate the $\mathcal F_{\rm old}$
# * Propose a new set of parameters $\theta_{\rm prop}$, calculate the new corresponding $\mathcal F_{\rm prop}$. How you propose the new parameters is not essential as long as the probability of going from one set of parameters to the next is the same as the inverse: $P(\theta_a \to \theta_b) = P(\theta_b \to \theta_a)$. For this, we normally take Gaussian displacements with some (relatively small) standard deviation.
# * Compare the new and old likelihoods-priors:
#     * If $\mathcal F_{\rm prop} > \mathcal F_{\rm old}$, accept the step: $\theta_{\rm new} = \theta_{\rm prop}$
#     * Otherwise, accept with probability $P_{\rm accept} = \mathcal F_{\rm prop}/\mathcal F_{\rm old}$
# * If accepted, $\theta_{\rm new} = \theta_{\rm prop}$ and record the step; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Update $\theta_{\rm old} = \theta_{\rm new}$
# * Repeat
#
# The MC chain keeps going until the desired number of steps or, ideally, when a suitable convergence test, like for example the [Gelman-Rubin test](https://bookdown.org/rdpeng/advstatcomp/monitoring-convergence.html), is satisfied.
# Today we will just set a limit to the total number of steps, but please feel free to implement and test your favourite convergence test!
#
# Looking at equation (4), you can convince yourself that
# $$
# \frac{\mathcal L_a}{\mathcal L_b} = \exp\left(\frac{\chi_b^2 - \chi_a^2}{2}\right)
# $$
#
# (This is useful because $\chi^2$ can be large, so we want to avoid the likelihoods evaluating to `0.` -- computers don't like dividing by zero, unfortunately)
#
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and the corresponding chi squared $\chi_{\rm old}^2$ (to be clear, for us this implies calculating a series of 580 integrals and comparing each with the observed values)
# * Propose new parameters $\theta_{\rm prop}$ and calculate the corresponding chi squared $\chi_{\rm prop}^2$
# * Draw a random number $r \in [0,1]$
# * Accept the step if
# $$
# r < \exp\left(\frac{\chi_{\rm old}^2 - \chi_{\rm prop}^2}{2}\right) \frac{P(\theta)_{\rm prop}}{P(\theta)_{\rm old}}
# $$
#     * If accepted, update $\theta_{\rm old} = \theta_{\rm prop}$, and record; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Repeat

# %%
# We can vectorize the mu function to massively speed up the analysis
# This allows us to apply the mu function to an array of redshift values at once, 
# improving performance compared to looping through each value.
function = np.vectorize(mu)

# The way to speed up this function even further is to create a new function which already does the operations on 
# the redshifts and just takes the parameters as variables instead of repeating the operations on the redshifts
mu_vec = lambda h, OmegaM, OmegaL: function(dataframe['redshift'], h, OmegaM, OmegaL)

# defining the chi2 function
# This function calculates the chi-squared statistic, which measures the goodness of fit 
# between the model predictions (using mu_vec) and the observed distance modulus values.
def chi2(h, OmegaM, OmegaL):
    return np.sum(np.square(np.subtract(mu_vec(h, OmegaM, OmegaL), dataframe['distance_modulus'])) / (np.square(dataframe['distance_modulus_error'])))

# defining the function to generate the new parameters
# This function generates new parameters by sampling from normal distributions centered 
# around the current parameters, with specified standard deviations for each parameter.
def new_parameters(h, OmegaM, OmegaL):
    new_h = np.random.normal(h, 0.05)
    new_OmegaM = np.random.normal(OmegaM, 0.01)
    new_OmegaL = np.random.normal(OmegaL, 0.01)
    return np.array([new_h, new_OmegaM, new_OmegaL])

# defining the criteria on which to accept or reject the new parameters
# This function implements the Metropolis-Hastings algorithm to decide whether to accept 
# the proposed parameters based on their chi-squared values.
def accept_move(chi2current, chi2prop):
    # generating a random value between 0 and 1
    r = np.random.uniform(0, 1)
    # accept if the chi2 of the proposed parameters is lower than that of the current parameters
    # or if the chi2 of the proposed parameters is higher than that of the current parameters, 
    # but the random value is smaller than the exponential of the difference between the two chi2 values divided by 2
    if chi2prop < chi2current:
        return True
    elif r <= min(1, np.exp(-(chi2prop - chi2current) / 2)):
        return True
    # otherwise reject
    else:
        return False

# Initialize variables for the Markov Chain Monte Carlo (MCMC) process
# This includes lists for accepted and rejected chi-squared values, 
# a counter for the number of steps, and the initial parameter values.
accepted = []
rejected = []
chain = []
n = 0
N_steps = 580  # Initialize the number of steps
burn_in = 15   # add a burn in period of 15 steps
theta0 = np.array([0.5, 0.5, 0.5])  # Initialize the parameters

filename = "MC_Chain_SNIa.dat" 
# Initialize the chi2 for the current parameters
chi2current = chi2(*theta0)

# Open the file and write the header, while the loop is running we will write the accepted values in the file
# This allows us to save the results of the MCMC process for later analysis.
with open(filename, 'w') as f:
    f.write("h\tOmega_M\tOmega_L\tOmegaK\tchi2\t")
    
    # Main loop for the MCMC process
    # Propose new parameters, calculate chi-squared, and decide whether to accept or reject the new parameters.
    while n < N_steps:
        # Propose a new set of parameters by generating a random normal distribution around the current parameters 
        thetaprop = new_parameters(*theta0)
        # Initialize the chi2 for the proposed parameters
        chi2prop = chi2(*thetaprop)
        # Accept or reject the proposed parameters using the function accept_move
        if accept_move(chi2current, chi2prop):
            # if the move is accepted, we set the current parameters to the proposed parameters
            theta0 = thetaprop
            # and the current chi2 to the chi2 of the proposed parameters
            chi2current = chi2prop
            # and lastly we record the new parameters and chi2 value in the .dat file
            if n >= burn_in:    
                f.write(f"\n{theta0[0]}\t{theta0[1]}\t{theta0[2]}\t{1 - theta0[1] - theta0[2]}\t{chi2current}\t")
                chain.append(theta0)
            accepted.append
            # we increase the counter by 1 nonetheless 
        n += 1

# %%
# load the data into a pandas dataframe
data = pd.read_csv("MC_Chain_SNIa.dat", sep="\t")
data
# Out:
#            h   Omega_M   Omega_L    OmegaK        chi2  Unnamed: 5
# 0   0.668755  0.489019  0.485699  0.025282  662.125923         NaN
# 1   0.669642  0.483137  0.475372  0.041491  659.918801         NaN
# 2   0.678409  0.475037  0.487479  0.037484  651.004624         NaN
# 3   0.678618  0.459509  0.480377  0.060114  645.636995         NaN
# 4   0.676099  0.456342  0.468039  0.075619  645.826407         NaN
# 5   0.669728  0.430012  0.475557  0.094431  643.071202         NaN
# 6   0.681722  0.425756  0.458816  0.115428  640.685648         NaN
# 7   0.669426  0.420484  0.472985  0.106531  641.889413         NaN
# 8   0.673142  0.411274  0.465584  0.123142  631.059372         NaN
# 9   0.675817  0.421430  0.474268  0.104301  629.792675         NaN
# 10  0.677000  0.432016  0.473052  0.094931  633.975453         NaN
# 11  0.673876  0.440560  0.474807  0.084633  638.339858         NaN
# 12  0.673544  0.441393  0.476348  0.082260  638.699192         NaN
# 13  0.679881  0.451627  0.496819  0.051553  638.076036         NaN
# 14  0.677044  0.462487  0.506686  0.030826  638.485954         NaN
# 15  0.682501  0.456426  0.506528  0.037046  641.630579         NaN
# 16  0.677678  0.434686  0.514588  0.050726  625.274962         NaN
# 17  0.681694  0.419093  0.534975  0.045932  614.658810         NaN
# 18  0.683097  0.409022  0.548067  0.042911  608.295016         NaN
# 19  0.684611  0.410184  0.568692  0.021125  604.760614         NaN
# 20  0.681749  0.418286  0.564621  0.017094  607.932244         NaN
# 21  0.681464  0.427733  0.576104 -0.003837  609.032607         NaN
# 22  0.681717  0.424923  0.585682 -0.010605  606.276705         NaN
# 23  0.681527  0.433694  0.590949 -0.024644  608.294187         NaN
# 24  0.687217  0.422071  0.586953 -0.009023  607.693048         NaN
# 25  0.681024  0.413901  0.586586 -0.000487  603.416096         NaN
# 26  0.686571  0.405259  0.586265  0.008476  600.269182         NaN
# 27  0.690387  0.397343  0.590554  0.012103  601.701184         NaN
# 28  0.685746  0.394282  0.590431  0.015287  595.021632         NaN
# 29  0.681862  0.394538  0.602042  0.003420  595.824109         NaN
# 30  0.684680  0.392006  0.608365 -0.000372  591.546751         NaN
# 31  0.685893  0.400818  0.609982 -0.010800  593.462518         NaN
# 32  0.686256  0.396113  0.606973 -0.003086  592.590069         NaN
# 33  0.686368  0.396245  0.601032  0.002723  593.776505         NaN
# 34  0.685426  0.396142  0.598829  0.005029  594.001095         NaN
# 35  0.682154  0.391574  0.590353  0.018074  595.955238         NaN
# 36  0.686354  0.406482  0.603109 -0.009591  596.771697         NaN
# 37  0.684651  0.396113  0.607973 -0.004086  592.707888         NaN
# 38  0.684990  0.402059  0.614397 -0.016457  593.241478         NaN
# 39  0.684840  0.389032  0.620132 -0.009164  589.210283         NaN
# 40  0.683400  0.369006  0.617418  0.013577  587.524764         NaN
# 41  0.691374  0.367663  0.631322  0.001015  582.101390         NaN
# 42  0.693087  0.353041  0.637042  0.009917  578.464728         NaN
# 43  0.692997  0.340052  0.639996  0.019952  574.430605         NaN
# 44  0.686595  0.341057  0.653355  0.005588  577.646520         NaN

# %% [markdown]
# After completion of the programme, your MC chain will (*hopefully*) look something like this:
#
# `#Omega_m  Omega_L  h`
#
# `0.297     0.703    0.698`
#
# `0.285     0.715    0.701`
#
# `0.288     0.712    0.699`
#
# `...`

# %% [markdown]
# ## <span style='color:deepskyblue'>Plotting: GetDist</span>
#
# We will do the plots with [`GetDist`](https://getdist.readthedocs.io/en/latest/plot_gallery.html).
#
# The plot gallery contains a lot of useful examples, you should be able to read them fairly easily and see which applies to your situation. Look for both (triangle) plots and for parameter estimation.
#
# Note that many `GetDist` functions require arguments of type `MCSamples`; make sure you convert your lists accordingly.

# %%
# These are just randomly generated values. YOU WILL HAVE TO USE THE RESULTS OF YOUR MCMC CHAIN!
h, OmegaM, OmegaL, Omegak = data["h"], data["Omega_M"], data["Omega_L"], data["OmegaK"]

# Here let's just define variable names, labels, and so on
my_labels = [r'h', r'\Omega_m', r'\Omega_\Lambda', r'\Omega_k']
my_names = ['h', 'OmegaM', 'OmegaL', 'Omegak']
my_dim = 4 # The number of variables we're plotting

my_samples = np.array([h, OmegaM, OmegaL, Omegak]) # This creates a higher-dimensional array with all our data,
my_samples = np.transpose(np.reshape(my_samples,(my_dim,int(my_samples.size/my_dim)))) # and this reshapes it in a convenient form...
samples1 = MCSamples(samples = my_samples, labels = my_labels, names = my_names) # ... to create an "MCSamples" data type, which GetDist can use

conf_level = 0.6827 # The usual 1-sigma confidence level

# Let's print a table with the 1D posteriors (confidence levels)
for nam in my_names:
    print(round(samples1.confidence(nam,(1.-conf_level)/2.,upper=False),2), \
          " < ", nam , " < ", round(samples1.confidence(nam,(1.-conf_level)/2.,upper=True),2),\
          " at " , int(100*conf_level),"\b% CL")
print("\n\n")

#Triangle corner plot
j = plots.getSubplotPlotter(subplot_size=3)
j.settings.axes_labelsize = 22
j.settings.axes_fontsize = 16
j.triangle_plot(samples1, filled = True, title_limit=1)
# Out:
# Removed no burn in
# 0.68  <  h  <  0.69  at  68% CL
# 0.39  <  OmegaM  <  0.45  at  68% CL
# 0.48  <  OmegaL  <  0.61  at  68% CL
# -0.0  <  Omegak  <  0.08  at  68% CL
# WARNING:root:2D kernel density bandwidth optimizer failed for h, OmegaM. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for h, OmegaL. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for h, Omegak. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for OmegaM, OmegaL. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for OmegaM, Omegak. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for OmegaL, Omegak. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# Here I will attempt to make a convergence test

# %%
class mcmc:
    def __init__(self):
        self.accepted = []
        self.c = []

        # Initialize the list of rejected chi2 values
        self.rejected = []

        # Initialize the number of steps
        self.N_steps = 580

        # Initialize the parameters
        self.burn_in = 15  
    
    def run_chain(self,i):
        n = 0

        # Initialize the parameters, using a uniform distribution and some prior knowledge about the parameters
        theta0 = np.random.uniform([0.5, 0.3, 0.5], [1, 0.4, 0.9])

        # Initialize the chi2 for the current parameters
        chi2current=chi2(*theta0)
        filename = f"MC_Chain_SNIa_{i}.dat"
        
        # Open the file and write the header, while the loop is running we will write the accepted values in the file
        # the file is automatically closed at the end. This is better coding practise than using f.close() at the end. 
        with open(filename, 'w') as f:
            f.write("h\tOmega_M\tOmega_L\tOmegaK\tchi2\t")
            while n < self.N_steps:
                # Propose a new set of parameters by generating a random normal distribution around the current parameters 
                thetaprop = new_parameters(*theta0)
                # Initialize the chi2 for the proposed parameters
                chi2prop = chi2(*thetaprop)
                # Accept or reject the proposed parameters using the function accept_move
                if accept_move(chi2current,chi2prop):
                    # if the move is accepted, we set the current parameters to the proposed parameters
                    theta0 = thetaprop
                    # and the current chi2 to the chi2 of the proposed parameters
                    chi2current = chi2prop
                    # and lastly we record the new parameters and chi2 value in the .dat file
                    if n >= self.burn_in: 
                        f.write(f"\n{thetaprop[0]}\t{thetaprop[1]}\t{thetaprop[2]}\t{1-thetaprop[1]-thetaprop[2]}\t{chi2prop}\t")
                        self.accepted.append(chi2prop)
                    self.c.append(theta0)
                else:
                    self.rejected.append(chi2prop)
                # we increase the counter by 1 nonetheless 
                n += 1

# %%
class mcmc_convergence_test(mcmc):
    # We inherit the mcmc class
    def __init__(self, Nchains):

        # We call the __init__ function of the mcmc class
        super().__init__()
        self.Nchains = Nchains
        self.chains = [mcmc() for i in range(self.Nchains)]
        self.data = {}

    def run_convergence_test(self):

        # Initialize the chains
        for chain in self.chains:
            print("Running chain", self.chains.index(chain)+1, "of", self.Nchains)
            
            # Run the chains
            chain.run_chain(self.chains.index(chain)+1)

        # Calculate the within-chain variances
        # We use ddof=1 to calculate the sample variance instead of the population variance
        # This is because we are calculating the variance of a sample of the population
        W = np.mean([np.var(chain.accepted, ddof=1) for chain in self.chains])

        # Calculate the between-chain variances
        # We use axis=0 to calculate the mean of each column
        # This is because we want to calculate the mean of each parameter
        # theta_bar is a 2D array with shape (Nchains, Nparameters) where Nchains is the number of chains and Nparameters is the number of parameters
        # theta_bar[i,j] is the mean of the jth parameter for the ith chain
        theta_bar = np.mean([chain.accepted for chain in self.chains], axis=0)
        # B is the between-chain variance, which is the sum of the squared differences between the mean of each parameter and the mean of all parameters
        B = self.N_steps / (self.Nchains - 1) * np.sum(np.square(theta_bar - np.mean(theta_bar, axis=0)), axis=0)

        # Calculate the estimated variances
        # N is the total number of steps taken
        N = sum([len(chain.accepted) for chain in self.chains])
        # V_hat is the weighted average of W and B
        V_hat = (N-1)/N * W + B/N

        # Calculate the potential scale reduction factor, which is the square root of V_hat divided by W
        R_hat = np.sqrt(V_hat/W)

        # store the results
        self.data["Number of chains"]=self.Nchains
        self.data["Within-chain variance (W)"]=W
        self.data["Between-chain variance (B)"]=B
        self.data["Estimated variance (V_hat)"]=V_hat
        self.data["Potential scale reduction factor (R_hat)"]=R_hat

        # Check for convergence
        if R_hat < 1.1:
            print("The chains have converged.")
        else:
            print("The chains have not yet converged.")
    def plot(self):
        for chains in self.chains:
            plt.plot(chains.accepted, label=f"Chain {self.chains.index(chains)+1}")

        plt.legend()

# %%
# determine the mean of each parameter for each chain after convergence and store them in a dictionary
params = {"h":[], "Omega_M":[], "Omega_L":[], "OmegaK":[]}

for i in range(20):

    # loop over the 20 chains
    with open(f"MC_Chain_SNIa_{i+1}.dat", 'r') as f:

        # read the data from the .dat file
        data = pd.read_csv(f, sep="\t")
        
        # calculate the mean of each parameter and append it to the corresponding list in the dictionary
        params["h"] += [np.mean(data['h'])]
        params["Omega_M"]+= [np.mean(data['Omega_M'])]
        params["Omega_L"]+= [np.mean(data['Omega_L'])]
        params["OmegaK"]+= [np.mean(data['OmegaK'])]

# %%
SPEED_OF_LIGHT = 299792.458 # in km/s

# Function for calculating the luminosity distance
def tlm(z, h, OmegaM, OmegaL, OmegaK):
    return 10.**6 * SPEED_OF_LIGHT / h * (1.+z) * \
    integrate.quad(lambda x: 1. / np.sqrt(OmegaM * (1.+x)**3 + OmegaL +OmegaK *(1+x)**2), 0., z)[0]

# Function for calculating the distance modulus
def mu1(z, h, OmegaM, OmegaL, OmegaK):
    return 5. * (-1. + np.log10(tlm(z, h, OmegaM, OmegaL, OmegaK)))

# %%
# Create a figure for the plots
plt.figure(figsize=(15, 5))

# Sort the redshift values
zsort = sorted(zs)

# Get best fit parameters
best_fit_params = samples1.getMeans()
h_best, OmegaM_best, OmegaL_best, OmegaK_best = best_fit_params

# Calculate distance modulus for best fit parameters
d_best_fit = [mu1(z, h_best, OmegaM_best, OmegaL_best, OmegaK_best) for z in zsort]

# Calculate the min and max values for the parameters
percentiles = np.percentile(samples1.samples, [16, 84], axis=0)
h_min, h_max = percentiles[0, 0], percentiles[1, 0]
OmegaM_min, OmegaM_max = percentiles[0, 1], percentiles[1, 1]
OmegaL_min, OmegaL_max = percentiles[0, 2], percentiles[1, 2]
OmegaK_min, OmegaK_max = percentiles[0, 3], percentiles[1, 3]

# Calculate distance modulus for min and max parameters
d_min = [mu1(z, h_min, OmegaM_min, OmegaL_min, OmegaK_min) for z in zsort]
d_max = [mu1(z, h_max, OmegaM_max, OmegaL_max, OmegaK_max) for z in zsort]

# Print to check values
print("d_min:", d_min)
print("d_max:", d_max)
print("d_best_fit:", d_best_fit)
print("Length of zsort:", len(zsort))
print("Length of d_min:", len(d_min))
print("Length of d_max:", len(d_max))

# Calculate the best fit values
best_fit_h = samples1.mean('h')
best_fit_OmegaM = samples1.mean('OmegaM')
best_fit_OmegaL = samples1.mean('OmegaL')

# Generate the best fit distance modulus values
best_fit_values = mu_vec(best_fit_h, best_fit_OmegaM, best_fit_OmegaL)

# Print the best fit values
print("Best fit distance modulus values:")
for z, d in zip(dataframe['redshift'], best_fit_values):
    print(f"Redshift: {z}, Distance Modulus: {d}")

# Plot distance modulus calculated using the new parameters versus redshift
plt.subplot(1, 2, 1)
plt.xlabel("Redshift")
plt.ylabel("Distance Modulus")
plt.errorbar(dataframe['redshift'], 
             dataframe['distance_modulus'], 
             yerr=dataframe["distance_modulus_error"], 
             fmt='o', 
             color='black', 
             ecolor='darkcyan', 
             markersize=4)

# Now plot the best fit line
plt.plot(zsort,
         best_fit_values,  
         color='red', 
         label='Best fit',
         lw=3,
         zorder=10)

# Create another figure to analyze d_min, d_max, and d_best_fit -> basically this is my error bars but clearer
plt.figure(figsize=(15, 5))
plt.plot(zsort, d_min, label='d_min', color='blue', linestyle='--')
plt.plot(zsort, d_max, label='d_max', color='green', linestyle='--')
plt.plot(zsort, d_best_fit, label='d_best_fit', color='red', linestyle='-')
plt.xlabel("Redshift")
plt.ylabel("Distance Modulus")
plt.legend()
plt.show()
# Out:
# d_min: [44.29613291229482, 44.29613291229482, 44.29613291229482, 44.30008212717799, 44.31070148835837, 44.32026448640614, 44.32517480320478, 44.32517480320478, 44.339554105874804, 44.359003906504824, 44.43767683173425, 44.43767683173425, 44.47843457747127, 44.481259746131876, 44.48457016060032, 44.49853580698549, 44.51302920464802, 44.535577375471995, 44.537282223408724, 44.569557023787816, 44.59294736005336, 44.59984018211259, 44.60912435222191, 44.60912435222191, 44.64749969293078, 44.68783159152231, 44.73437215621692, 44.78005417083309, 44.803433689290785, 44.83804843418384, 44.83804843418384, 44.84536370441651, 44.872132762040444, 44.883266971028974, 44.96863432535035, 44.982118894252785, 45.01408278000798, 45.02463632849598, 45.04559469096273, 45.0560004429153, 45.08692947142479, 45.11672839279931, 45.12751213610001, 45.135541428813035, 45.14752998770865, 45.14752998770865, 45.177224125091115, 45.22585334385327, 45.22585334385327, 45.23268971749023, 45.23545342331015, 45.25529043593123, 45.26400864429242, 45.26400864429242, 45.28621847759194, 45.32004751854947, 45.32493077280971, 45.32925230485547, 45.346209213183, 45.347549022692064, 45.35791158875216, 45.37696573518656, 45.39264680106144, 45.40155833888524, 45.41043454743453, 45.428082105416635, 45.46296549904323, 45.47160214125085, 45.49731415207965, 45.50581969838074, 45.50904336409192, 45.51429309934274, 45.54695344326862, 45.5561864256784, 45.573484864882175, 45.61694910857596, 45.629678105877225, 45.63519245317471, 45.6456879870046, 45.65881077704765, 45.693044290907224, 45.70053163774251, 45.70767961350527, 45.762259301921226, 45.80740593243681, 45.818724546678624, 45.844062621289574, 45.86072522628349, 45.86615573540162, 45.880285994068394, 45.880285994068394, 45.880285994068394, 45.887461327766, 45.908851323086985, 45.908851323086985, 45.93004034208946, 45.93200786599734, 45.96491904933735, 45.96491904933735, 45.97183056937907, 45.97183056937907, 45.97183056937907, 45.974176836248006, 45.999266986541386, 46.012861197659085, 46.026374087247525, 46.027207284644206, 46.05980694779474, 46.06643458507544, 46.073042850641805, 46.079631859502655, 46.10579759254135, 46.10579759254135, 46.10579759254135, 46.13166415820687, 46.20877983628389, 46.22611420575542, 46.22611420575542, 46.22611420575542, 46.23841524553314, 46.25412474151184, 46.25552535917075, 46.2628189351416, 46.32860649574319, 46.42101951348286, 46.471397865161926, 46.49343534508547, 46.574228438826424, 46.581255850017, 46.584787794330396, 46.59529851782834, 46.658331469671104, 46.721600860370664, 46.73734007784716, 46.81829489041044, 46.88508422374877, 46.90467214931016, 46.91061929850733, 46.91755342340229, 46.95469424260292, 46.960111139854305, 47.054595546816614, 47.08554491733952, 47.1185069891603, 47.14713261550908, 47.15536400710442, 47.23941018498756, 47.27544313967037, 47.30258773052639, 47.30258773052639, 47.32560423460966, 47.43504570398621, 47.465155592142885, 47.50775860214336, 47.52309374467902, 47.55097731047768, 47.59695920090322, 47.6626019348332, 47.67577711996516, 47.68233700965831, 47.717639970703665, 47.85908971143552, 47.88161632790268, 47.971640706457556, 47.97676125490312, 48.018896736052305, 48.1366189896907, 48.173855565579785, 48.174032588931595, 48.178243811644855, 48.22383542978579, 48.260790868465165, 48.35915782535507, 48.36438163667359, 48.382945389080724, 48.547786215852426, 48.58836915523525, 48.67611669574966, 48.71728077253398, 48.808864670204926, 48.8427040210502, 48.875401098088204, 48.89377254836785, 48.90061918396836, 48.9404954051956, 49.000772215660724, 49.02462410250678, 49.02786232022144, 49.03021969503197, 49.068541815771944, 49.07247872423386, 49.109528609099115, 49.11945480383136, 49.13059872359463, 49.33447330726088, 49.34460180130887, 49.3658394384054, 49.37223552493063, 49.38066735400945, 49.39753007464695, 49.40748527928636, 49.4191998709494, 49.494891551184864, 49.53732051318484, 49.546632548761416, 49.559481048640635, 49.60268971261427, 49.6158004090679, 4 ...
# d_max: [43.958037824780185, 43.958037824780185, 43.958037824780185, 43.961987429825, 43.97260784376245, 43.982171794377734, 43.9870826019678, 43.9870826019678, 44.00146334843684, 44.0209151176734, 44.09959619320067, 44.09959619320067, 44.140358282199, 44.14318375503578, 44.14649452644341, 44.16046168482447, 44.1749566622334, 44.1975073124243, 44.199212348903316, 44.23149074750637, 44.254883726116915, 44.26177733244741, 44.271062562978045, 44.271062562978045, 44.30944233673456, 44.34977898221799, 44.39632513869165, 44.44201276346626, 44.46539520059636, 44.50001432676156, 44.50001432676156, 44.50733053217219, 44.53410303980341, 44.54523869676119, 44.6306174115155, 44.644103817515315, 44.67607210537125, 44.68662712209168, 44.70758842232079, 44.71799564380301, 44.74892908349379, 44.77873231687284, 44.78951763578791, 44.79754810694005, 44.80953843379383, 44.80953843379383, 44.83923699400404, 44.887873592755156, 44.887873592755156, 44.89471101769812, 44.89747514950004, 44.91731523625664, 44.926034804924385, 44.926034804924385, 44.948248129367514, 44.98208255965494, 44.98696659909905, 44.99128882754065, 45.008248482354134, 45.00958850982183, 45.01995276638178, 45.039010043191226, 45.054693706793515, 45.06360672962086, 45.072484423601075, 45.09013495372667, 45.12502429676306, 45.13366242738961, 45.15937890603267, 45.16788594245721, 45.17111017452696, 45.176360833968474, 45.209026980178336, 45.21826161943284, 45.23556318265221, 45.27903539125617, 45.291766752827854, 45.297282128852004, 45.307779628219805, 45.32090488980661, 45.355144925077354, 45.36263371260085, 45.369783068600796, 45.424373454051576, 45.4695291477085, 45.48085006521832, 45.50619334173544, 45.52285940235037, 45.52829104370079, 45.54242426238251, 45.54242426238251, 45.54242426238251, 45.54960110691272, 45.57099563724697, 45.57099563724697, 45.59218919503324, 45.59415714275318, 45.627075475289985, 45.627075475289985, 45.63398851118768, 45.63398851118768, 45.63398851118768, 45.63633529379847, 45.66143099595016, 45.675028243371855, 45.68854417093217, 45.68937755629869, 45.721984633699115, 45.72861379267244, 45.73522358034733, 45.74181411173251, 45.76798593902368, 45.76798593902368, 45.76798593902368, 45.79385860558372, 45.870992932324334, 45.88833159049861, 45.88833159049861, 45.88833159049861, 45.90063569561621, 45.9163491329781, 45.91775010350051, 45.925045520851754, 45.99084998837938, 46.083287686609616, 46.133679967032315, 46.15572364809925, 46.23654005399855, 46.24356953660099, 46.247102524678574, 46.25761636497002, 46.32066834719658, 46.38395743751269, 46.399701650841045, 46.480682775695136, 46.54749461550479, 46.56708928252323, 46.573038491347134, 46.579975025269036, 46.617128888053536, 46.622547707597725, 46.71706647885144, 46.748027456688774, 46.78100208624262, 46.80963878448583, 46.81787338878614, 46.90195312505697, 46.93800089773675, 46.9651568263274, 46.9651568263274, 46.98818306342774, 47.09767235400591, 47.12779585815146, 47.170418482788236, 47.18576078733488, 47.21365751552991, 47.25966151182428, 47.32533668754989, 47.338518512027825, 47.3450817236143, 47.38040274833101, 47.521928119163704, 47.54446727725947, 47.63454319982344, 47.63966674987127, 47.6818272222528, 47.79962213601571, 47.836882594155554, 47.83705973210328, 47.84127368392407, 47.88689521675476, 47.923875406266916, 48.022310505560846, 48.02753802971967, 48.046115054751944, 48.211079277584766, 48.25169418192341, 48.33951308452164, 48.38071172825002, 48.47237512118713, 48.50624477372838, 48.53897161829877, 48.55736000771421, 48.56421299586113, 48.6041266486524, 48.66446146846354, 48.688336794255804, 48.69157821560101, 48.693937925852076, 48.73229839835525, 48.73623928828741, 48.77332702625463, 48.78326348121749, 48.794418980323414, 48.99851710184641, 49.00865730090588, 49.02991967260347, 49.0363232594475, 49.04476501236807, 49.06164770413868, 49.071614777486204, 49.083343410417804, 49.15912780073267, 49.20161026614406, 49.21093419482866, 49.223799194358016, 49.26706411780705, 49.28019212289479, 49 ...
# d_best_fit: [44.11867344549819, 44.11867344549819, 44.11867344549819, 44.12262334034847, 44.13324453600278, 44.14280919362173, 44.147720365363405, 44.147720365363405, 44.16210218262073, 44.18155541075077, 44.260242512630185, 44.260242512630185, 44.30100780409034, 44.3038335009759, 44.30714453525749, 44.321112806709664, 44.33560894626353, 44.35816141875878, 44.35986659373174, 44.39214763318766, 44.415542548410436, 44.422436729106856, 44.43172273592543, 44.43172273592543, 44.470105750966724, 44.510445860148025, 44.55699608748488, 44.60268778640221, 44.62607233910923, 44.660694635899745, 44.660694635899745, 44.66801151728498, 44.694786516279905, 44.70592321773819, 44.7913101044005, 44.80479782806211, 44.83676926902657, 44.847325336054105, 44.868288735804086, 44.87869700650017, 44.909633591646745, 44.939439893923705, 44.95022633278343, 44.95825764106697, 44.9702492230264, 44.9702492230264, 44.999950918862865, 45.04859273638264, 45.04859273638264, 45.05543090340082, 45.058195335790394, 45.07803759012141, 45.086758117022455, 45.086758117022455, 45.10897389813596, 45.142812113558435, 45.147696703733544, 45.15201942047391, 45.168980999640354, 45.17032117972549, 45.18068661950889, 45.199746085075354, 45.215431562771975, 45.224345621725874, 45.23322435146994, 45.25087695203534, 45.285770431600966, 45.29440959545376, 45.32012917160175, 45.328637239803484, 45.33186186385361, 45.337113162729786, 45.36978331770059, 45.379019099838715, 45.39632281579543, 45.43980050002969, 45.45253348339961, 45.458049564582396, 45.468548410406704, 45.48167536348782, 45.515919853438255, 45.523409623417244, 45.53055992008771, 45.58515757730264, 45.63031940640437, 45.6416418794252, 45.66698866351409, 45.68365704997605, 45.689089452656255, 45.70322465999037, 45.70322465999037, 45.70322465999037, 45.7104025186064, 45.73180008903898, 45.73180008903898, 45.752996683685765, 45.75496491468087, 45.78788801818499, 45.78788801818499, 45.79480206385285, 45.79480206385285, 45.79480206385285, 45.79714918987385, 45.82224858410306, 45.83584784711352, 45.849365788826375, 45.850199298732036, 45.88281128069361, 45.88944144441061, 45.89605223647048, 45.90264377188201, 45.92881961169315, 45.92881961169315, 45.92881961169315, 45.95469628503867, 46.03184279708867, 46.0491842443777, 46.0491842443777, 46.0491842443777, 46.061490340004, 46.07720633307069, 46.07860753219871, 46.0859041419683, 46.151719516037524, 46.244173001295565, 46.2945741218641, 46.316621722638985, 46.39745277683255, 46.404483554397075, 46.40801719458641, 46.41853298053357, 46.48159679003498, 46.54489802947795, 46.560645308769814, 46.64164248194315, 46.70846791748406, 46.72806663358387, 46.734017077340326, 46.7409550544304, 46.77811670765997, 46.78353667197055, 46.87807576423978, 46.90904354507051, 46.942025500427704, 46.97066862837718, 46.978905093256735, 47.063004128042806, 47.099060343809285, 47.12622270044497, 47.12622270044497, 47.14925443377513, 47.25877043748249, 47.28890146016535, 47.3315348486122, 47.34688106382261, 47.3747849519351, 47.42080089465381, 47.48649342663341, 47.49967877763148, 47.50624375042902, 47.54157431469476, 47.68313895005497, 47.70568451573895, 47.79578647035069, 47.800911521540534, 47.84308442997091, 47.960914878151144, 47.99818681763817, 47.9983640104449, 48.002579268081725, 48.04821503254465, 48.085206884637216, 48.18367357687439, 48.188902801012354, 48.207485885259906, 48.37250513346234, 48.41313391642718, 48.50098326428306, 48.54219639300218, 48.63389246507658, 48.6677743466226, 48.7005130846932, 48.71890818956528, 48.72576368640605, 48.76569201424577, 48.826049219689295, 48.849933469349395, 48.85317610505059, 48.8555366997561, 48.89391159944881, 48.89785397671571, 48.93495575838096, 48.94489598994724, 48.95605573594828, 49.160232769271495, 49.17037694412386, 49.19164766777392, 49.198053773974486, 49.20649885090392, 49.22338819969819, 49.23335920889756, 49.245092478629296, 49.320906960854984, 49.36340638625444, 49.372734045259385, 49.38560419629847, 49.42888648015529, 49.4420197631 ...
# Length of zsort: 580
# Length of d_min: 580
# Length of d_max: 580
# Best fit distance modulus values:
# Redshift: 0.015, Distance Modulus: 34.118675875043905
# Redshift: 0.015, Distance Modulus: 34.118675875043905
# Redshift: 0.015, Distance Modulus: 34.118675875043905
# Redshift: 0.0150270427632, Distance Modulus: 34.12262577861902
# Redshift: 0.0151, Distance Modulus: 34.13324699788879
# Redshift: 0.015166, Distance Modulus: 34.14281167696828
# Redshift: 0.0152, Distance Modulus: 34.14772285980137
# Redshift: 0.0152, Distance Modulus: 34.14772285980137
# Redshift: 0.0153, Distance Modulus: 34.16210470982228
# Redshift: 0.0154363, Distance Modulus: 34.18155798294981
# Redshift: 0.016, Distance Modulus: 34.26024527509883
# Redshift: 0.016, Distance Modulus: 34.26024527509883
# Redshift: 0.0163, Distance Modulus: 34.30101067055793
# Redshift: 0.016321, Distance Modulus: 34.3038363747946
# Redshift: 0.016345641, Distance Modulus: 34.30714741771372
# Redshift: 0.01645, Distance Modulus: 34.32111572588946
# Redshift: 0.016559, Distance Modulus: 34.33561190404552
# Redshift: 0.01673, Distance Modulus: 34.35816443760542
# Redshift: 0.016743, Distance Modulus: 34.35986961724595
# Redshift: 0.016991, Distance Modulus: 34.392150746427575
# Redshift: 0.017173, Distance Modulus: 34.415545728322606
# Redshift: 0.017227, Distance Modulus: 34.42243992893523
# Redshift: 0.0173, Distance Modulus: 34.43172596277527
# Redshift: 0.0173, Distance Modulus: 34.43172596277527
# Redshift: 0.017605, Distance Modulus: 34.470109091929075
# Redshift: 0.0179312833626, Distance Modulus: 34.51044932535486
# Redshift: 0.0183152320362, Distance Modulus: 34.55699970176401
# Redshift: 0.0187, Distance Modulus: 34.602691553182
# Redshift: 0.0189, Distance Modulus: 34.626076186386946
# Redshift: 0.0192, Distance Modulus: 34.66069860549973
# Redshift: 0.0192, Distance Modulus: 34.66069860549973
# Redshift: 0.019264, Distance Modulus: 34.668015513224965
# Redshift: 0.0195, Distance Modulus: 34.694790610091594
# Redshift: 0.019599, Distance Modulus: 34.70592735295419
# Redshift: 0.0203747245299, Distance Modulus: 34.791314571157834
# Redshift: 0.0205, Distance Modulus: 34.80480234954416
# Redshift: 0.0208, Distance Modulus: 34.83677392289476
# Redshift: 0.0209, Distance Modulus: 34.84733003446959
# Redshift: 0.0211, Distance Modulus: 34.86829352394177
# Redshift: 0.0212, Distance Modulus: 34.87870183981268
# Redshift: 0.0215, Distance Modulus: 34.90963856173814
# Redshift: 0.021793, Distance Modulus: 34.9394449994179
# Redshift: 0.0219, Distance Modulus: 34.95023148817205
# Redshift: 0.0219800059146, Distance Modulus: 34.95826283391879
# Redshift: 0.0221, Distance Modulus: 34.97025447231659
# Redshift: 0.0221, Distance Modulus: 34.97025447231659
# Redshift: 0.0224, Distance Modulus: 34.999956310570695
# Redshift: 0.0229, Distance Modulus: 35.048598369624415
# Redshift: 0.0229, Distance Modulus: 35.048598369624415
# Redshift: 0.0229711675782, Distance Modulus: 35.05543657144501
# Redshift: 0.023, Distance Modulus: 35.05820101796428
# Redshift: 0.023208, Distance Modulus: 35.078043374741355
# Redshift: 0.0233, Distance Modulus: 35.08676394724248
# Redshift: 0.0233, Distance Modulus: 35.08676394724248
# Redshift: 0.023536, Distance Modulus: 35.10897984613591
# Redshift: 0.0239, Distance Modulus: 35.14281824549134
# Redshift: 0.023953, Distance Modulus: 35.14770286267775
# Redshift: 0.024, Distance Modulus: 35.15202560342039
# Redshift: 0.0241852990802, Distance Modulus: 35.16898727766409
# Redshift: 0.0242, Distance Modulus: 35.17032746532284
# Redshift: 0.024314, Distance Modulus: 35.180692963989245
# Redshift: 0.024525, Distance Modulus: 35.1997525392533
# Redshift: 0.0247, Distance Modulus: 35.21543810863286
# Redshift: 0.0248, Distance Modulus: 35.22435222026249
# Redshift: 0.0249, Distance Modulus: 35.23323100288989
# Redshift: 0.0251, Distance Modulus: 35.250883709844494
# Redshift: 0.0255, Distance Modulus: 35.28577740467769
# Redshift: 0.0256, Distance Modulus: 35.294416622865704
# Redshift: 0.0259, Distance Modulus: 35.32013636326265
# Redshift: 0.026, Distance Modulus: 35.32864448662833
# Redshift: 0.026038, Distance Modulus: 35.33186913169504
# Redshift: 0.0261, Distance Modulus: 35.33712046492565
# Redshift: 0.026489, Distance Modulus: 35.36979083725846
# Redshift: 0.0266, Distance Modulus: 35.379026681994375
# Redshift: 0.0268091974805, Distance Modulus: 35.396330516619436
# Redshift: 0.027342, Distance Modulus: 35.43980850717431
# Redshift: 0.0275, Distance Modulus: 35.45254158250944
# Redshift: 0.0275687259109, Distance Modulus: 35.45805770385556
# Redshift: 0.0277, Distance Modulus: 35.468556626667244
# Redshift: 0.027865, Distance Modulus: 35.48168367701913
# Redshift: 0.0283, Distance Modulus: 35.51592842610234
# Redshift: 0.0283960268116, Distance Modulus: 35.52341825381087
# Redshift: 0.028488, Distance Modulus: 35.53056860595206
# Redshift: 0.0292, Distance Modulus: 35.58516669848189
# Redshift: 0.029802136901, Distance Modulus: 35.63032890386901
# Redshift: 0.029955, Distance Modulus: 35.641651473602664
# Redshift: 0.0303, Distance Modulus: 35.666998477728754
# Redshift: 0.030529, Distance Modulus: 35.683667011593634
# Redshift: 0.030604, Distance Modulus: 35.68909946278384
# Redshift: 0.0308, Distance Modulus: 35.70323479743555
# Redshift: 0.0308, Distance Modulus: 35.70323479743555
# Redshift: 0.0308, Distance Modulus: 35.70323479743555
# Redshift: 0.0309, Distance Modulus: 35.71041272131305
# Redshift: 0.0312, Distance Modulus: 35.73181048876003
# Redshift: 0.0312, Distance Modulus: 35.73181048876003
# Redshift: 0.0315, Distance Modulus: 35.75300728226534
# Redshift: 0.031528, Distance Modulus: 35.75497553191462
# Redshift: 0.032, Distance Modulus: 35.78789895229037
# Redshift: 0.032, Distance Modulus: 35.78789895229037
# Redshift: 0.0321, Distance Modulus: 35.79481306567725
# Redshift: 0.0321, Distance Modulus: 35.79481306567725
# Redshift: 0.0321, Distance Modulus: 35.79481306567725
# Redshift: 0.0321340168614, Distance Modulus: 35.79716021478076
# Redshift: 0.0325, Distance Modulus: 35.822259858848405
# Redshift: 0.0327, Distance Modulus: 35.835859259545664
# Redshift: 0.0329, Distance Modulus: 35.8493773397624
# Redshift: 0.0329123710881, Distance Modulus: 35.8502108582621
# Redshift: 0.0334, Distance Modulus: 35.88282318146195
# Redshift: 0.0335, Distance Modulus: 35.88945341575753
# Redshift: 0.0336, Distance Modulus: 35.89606427859994
# Redshift: 0.0337, Distance Modulus: 35.902655884997884
# Redshift: 0.0341, Distance Modulus: 35.92883201079285
# Redshift: 0.0341, Distance Modulus: 35.92883201079285
# Redshift: 0.0341, Distance Modulus: 35.92883201079285
# Redshift: 0.0345, Distance Modulus: 35.954708973381265
# Redshift: 0.03572, Distance Modulus: 36.031856387723074
# Redshift: 0.036, Distance Modulus: 36.04919804636154
# Redshift: 0.036, Distance Modulus: 36.04919804636154
# Redshift: 0.036, Distance Modulus: 36.04919804636154
# Redshift: 0.0362, Distance Modulus: 36.0615042939257
# Redshift: 0.036457, Distance Modulus: 36.07722048342353
# Redshift: 0.03648, Distance Modulus: 36.078621700196265
# Redshift: 0.0366, Distance Modulus: 36.085918402199184
# Redshift: 0.0377, Distance Modulus: 36.151734635329284
# Redshift: 0.0393, Distance Modulus: 36.244189413789144
# Redshift: 0.0402, Distance Modulus: 36.29459128446656
# Redshift: 0.0406, Distance Modulus: 36.31663922385501
# Redshift: 0.0421, Distance Modulus: 36.397471576468824
# Redshift: 0.042233, Distance Modulus: 36.40450247133787
# Redshift: 0.0423, Distance Modulus: 36.408036170754684
# Redshift: 0.0425, Distance Modulus: 36.41855213403501
# Redshift: 0.0437189114895, Distance Modulus: 36.48161704160418
# Redshift: 0.0449766726113, Distance Modulus: 36.54491944521589
# Redshift: 0.045295, Distance Modulus: 36.56066702414757
# Redshift: 0.0469673346156, Distance Modulus: 36.64166580458139
# Redshift: 0.0483921953954, Distance Modulus: 36.70849265331471
# Redshift: 0.048818, Distance Modulus: 36.72809179952998
# Redshift: 0.048948, Distance Modulus: 36.734042375316555
# Redshift: 0.0491, Distance Modulus: 36.7409805072037
# Redshift: 0.049922, Distance Modulus: 36.77814300546123
# Redshift: 0.050043, Distance Modulus: 36.78356309528685
# Redshift: 0.0522, Distance Modulus: 36.87810447339691
# Redshift: 0.052926, Distance Modulus: 36.90907304414687
# Redshift: 0.05371, Distance Modulus: 36.94205586412563
# Redshift: 0.0544, Distance Modulus: 36.97069976297723
# Redshift: 0.0546, Distance Modulus: 36.9789364530455
# Redshift: 0.0566833670752, Distance Modulus: 37.06303787995932
# Redshift: 0.0576, Distance Modulus: 37.09909517495336
# Redshift: 0.0583, Distance Modulus: 37.12625836673534
# Redshift: 0.0583, Distance Modulus: 37.12625836673534
# Redshift: 0.0589, Distance Modulus: 37.14929082346053
# Redshift: 0.0618357646938, Distance Modulus: 37.25881046694469
# Redshift: 0.062668, Distance Modulus: 37.28894255162933
# Redshift: 0.0638640836964, Distance Modulus: 37.33157748965521
# Redshift: 0.0643, Distance Modulus: 37.346924276428076
# Redshift: 0.0651, Distance Modulus: 37.374829222933904
# Redshift: 0.0664403123402, Distance Modulus: 37.420846966253066
# Redshift: 0.0684, Distance Modulus: 37.486542192454515
# Redshift: 0.0688, Distance Modulus: 37.499728102340015
# Redshift: 0.069, Distance Modulus: 37.50629335571815
# Redshift: 0.070086, Distance Modulus: 37.5416254567522
# Redshift: 0.074605, Distance Modulus: 37.683196725518016
# Redshift: 0.0753501119815, Distance Modulus: 37.70574342174268
# Redshift: 0.0784, Distance Modulus: 37.795850111815035
# Redshift: 0.078577, Distance Modulus: 37.80097544313825
# Redshift: 0.0800481440021, Distance Modulus: 37.843150702381976
# Redshift: 0.0843, Distance Modulus: 37.96098816937669
# Redshift: 0.0856894593607, Distance Modulus: 37.99826247450254
# Redshift: 0.0856961170652, Distance Modulus: 37.9984396787294
# Redshift: 0.0858546441437, Distance Modulus: 38.00265520853117
# Redshift: 0.087589, Distance Modulus: 38.04829398054275
# Redshift: 0.0890194292939, Distance Modulus: 38.08528835433751
# Redshift: 0.0929368181997, Distance Modulus: 38.183762142186005
# Redshift: 0.0931494026855, Distance Modulus: 38.18899175929665
# Redshift: 0.0939086318905, Distance Modulus: 38.20757625364483
# Redshift: 0.100915, Distance Modulus: 38.372609000608804
# Redshift: 0.102715033935, Distance Modulus: 38.413241392194934
# Redshift: 0.106712340103, Distance Modulus: 38.50109895727509
# Redshift: 0.108638265524, Distance Modulus: 38.542316144765735
# Redshift: 0.113042644637, Distance Modulus: 38.63402174053509
# Redshift: 0.11471262087, Distance Modulus: 38.667907320539925
# Redshift: 0.116348502599, Distance Modulus: 38.700649727904384
# Redshift: 0.117277362889, Distance Modulus: 38.71904693656687
# Redshift: 0.117625328764, Distance Modulus: 38.72590322530813
# Redshift: 0.119671538006, Distance Modulus: 38.76583625156393
# Redshift: 0.12282889997, Distance Modulus: 38.82620084591976
# Redshift: 0.1241, Distance Modulus: 38.85008811766211
# Redshift: 0.124273528772, Distance Modulus: 38.853331168038764
# Redshift: 0.1244, Distance Modulus: 38.85569206528622
# Redshift: 0.126473161901, Distance Modulus: 38.894071962535406
# Redshift: 0.12668798909, Distance Modulus: 38.89801486177167
# Redshift: 0.128726735467, Distance Modulus: 38.93512163528615
# Redshift: 0.129278206634, Distance Modulus: 38.945063228997384
# Redshift: 0.1299, Distance Modulus: 38.95622451688999
# Redshift: 0.141787999126, Distance Modulus: 39.16043225051202
# Redshift: 0.1424046524, Distance Modulus: 39.17057808052996
# Redshift: 0.143705907, Distance Modulus: 39.19185231696516
# Redshift: 0.1441, Distance Modulus: 39.19825949239894
# Redshift: 0.144621085972, Distance Modulus: 39.206705986935006
# Redshift: 0.145668547261, Distance Modulus: 39.22359819848182
# Redshift: 0.146290296068, Distance Modulus: 39.23357091523721
# Redshift: 0.147025138268, Distance Modulus: 39.24530621107236
# Redshift: 0.151857894665, Distance Modulus: 39.32113423172103
# Redshift: 0.154632097239, Distance Modulus: 39.36364159516684
# Redshift: 0.155247328221, Distance Modulus: 39.3729710309223
# Redshift: 0.1561, Distance Modulus: 39.385843654203
# Redshift: 0.159, Distance Modulus: 39.42913443105128
# Redshift: 0.159889937748, Distance Modulus: 39.44227034653892
# Redshift: 0.160861854636, Distance Modulus: 39.45653796050012
# Redshift: 0.163795894987, Distance Modulus: 39.49912265491742
# Redshift: 0.170628396749, Distance Modulus: 39.59557463955309
# Redshift: 0.172, Distance Modulus: 39.614498864946846
# Redshift: 0.172742230556, Distance Modulus: 39.62468052278731
# Redshift: 0.173910056566, Distance Modulus: 39.64061748811127
# Redshift: 0.177600694977, Distance Modulus: 39.690330264720984
# Redshift: 0.178, Distance Modulus: 39.69565063791379
# Redshift: 0.17968564077, Distance Modulus: 39.71798754571508
# Redshift: 0.18, Distance Modulus: 39.72213144954301
# Redshift: 0.180119779968, Distance Modulus: 39.723708610962404
# Redshift: 0.181, Distance Modulus: 39.735268518391194
# Redshift: 0.18221823956, Distance Modulus: 39.75118094533494
# Redshift: 0.182548913397, Distance Modulus: 39.75548293216379
# Redshift: 0.183568404877, Distance Modulus: 39.76870042801933
# Redshift: 0.18581244671, Distance Modulus: 39.797553160246096
# Redshift: 0.186, Distance Modulus: 39.79994981044725
# Redshift: 0.188853175387, Distance Modulus: 39.83613249815329
# Redshift: 0.189706566951, Distance Modulus: 39.846855328241936
# Redshift: 0.192149980044, Distance Modulus: 39.87730865089426
# Redshift: 0.194316512142, Distance Modulus: 39.90400919898452
# Redshift: 0.196716068579, Distance Modulus: 39.9332581353676
# Redshift: 0.200611719928, Distance Modulus: 39.980039599233265
# Redshift: 0.202608679897, Distance Modulus: 40.003691721869394
# Redshift: 0.204979685349, Distance Modulus: 40.03149247058055
# Redshift: 0.205, Distance Modulus: 40.03172936356272
# Redshift: 0.210938395061, Distance Modulus: 40.10005405340359
# Redshift: 0.2115869815, Distance Modulus: 40.10740713345757
# Redshift: 0.211629598493, Distance Modulus: 40.10788954785917
# Redshift: 0.212548765094, Distance Modulus: 40.118272257089785
# Redshift: 0.213, Distance Modulus: 40.12335395868504
# Redshift: 0.214568258658, Distance Modulus: 40.14093739796765
# Redshift: 0.215, Distance Modulus: 40.145757028975396
# Redshift: 0.215543320953, Distance Modulus: 40.151809411730746
# Redshift: 0.216, Distance Modulus: 40.15688561867066
# Redshift: 0.216, Distance Modulus: 40.15688561867066
# Redshift: 0.216582821954, Distance Modulus: 40.16334941618683
# Redshift: 0.218, Distance Modulus: 40.178999092440826
# Redshift: 0.218347445403, Distance Modulus: 40.182821365475625
# Redshift: 0.218585189041, Distance Modulus: 40.18543352766854
# Redshift: 0.228528473881, Distance Modulus: 40.29237371613664
# Redshift: 0.232781107182, Distance Modulus: 40.33678963803419
# Redshift: 0.239, Distance Modulus: 40.400396762182645
# Redshift: 0.24, Distance Modulus: 40.41048036037928
# Redshift: 0.242504680476, Distance Modulus: 40.43556549673174
# Redshift: 0.244378876797, Distance Modulus: 40.4541785095367
# Redshift: 0.248508130676, Distance Modulus: 40.49472142664044
# Redshift: 0.2486, Distance Modulus: 40.495616275885354
# Redshift: 0.249511054792, Distance Modulus: 40.50447370694705
# Redshift: 0.25066763111, Distance Modulus: 40.51567478325686
# Redshift: 0.251740186424, Distance Modulus: 40.52601914548593
# Redshift: 0.252486060029, Distance Modulus: 40.53318858918619
# Redshift: 0.255490620022, Distance Modulus: 40.56187021380336
# Redshift: 0.256475742725, Distance Modulus: 40.57120577418946
# Redshift: 0.257497888297, Distance Modulus: 40.580856901065225
# Redshift: 0.257740303509, Distance Modulus: 40.58314055045607
# Redshift: 0.258028270562, Distance Modulus: 40.58585071516894
# Redshift: 0.26, Distance Modulus: 40.604331975830206
# Redshift: 0.260533476953, Distance Modulus: 40.60930985577006
# Redshift: 0.260586108317, Distance Modulus: 40.609800444444765
# Redshift: 0.263, Distance Modulus: 40.632202158593245
# Redshift: 0.263491026592, Distance Modulus: 40.63673557214386
# Redshift: 0.263647950642, Distance Modulus: 40.63818271592676
# Redshift: 0.265762479518, Distance Modulus: 40.65760484172992
# Redshift: 0.266, Distance Modulus: 40.65977747868211
# Redshift: 0.269, Distance Modulus: 40.687064347745064
# Redshift: 0.270434442827, Distance Modulus: 40.70001138202503
# Redshift: 0.271, Distance Modulus: 40.70509841347998
# Redshift: 0.273454768884, Distance Modulus: 40.727064301143756
# Redshift: 0.274, Distance Modulus: 40.731918208944194
# Redshift: 0.275440197435, Distance Modulus: 40.74469636124395
# Redshift: 0.277853422619, Distance Modulus: 40.765968736867315
# Redshift: 0.278, Distance Modulus: 40.76725524914181
# Redshift: 0.278924676328, Distance Modulus: 40.77535660288866
# Redshift: 0.27945473261, Distance Modulus: 40.779989295698236
# Redshift: 0.284, Distance Modulus: 40.819382041219434
# Redshift: 0.285, Distance Modulus: 40.82796988355915
# Redshift: 0.286, Distance Modulus: 40.83652968358813
# Redshift: 0.286618706522, Distance Modulus: 40.84181172823727
# Redshift: 0.288418344585, Distance Modulus: 40.857115468134744
# Redshift: 0.2912, Distance Modulus: 40.88059584358257
# Redshift: 0.292469756082, Distance Modulus: 40.89124462316403
# Redshift: 0.295585550063, Distance Modulus: 40.91719364107769
# Redshift: 0.297518833561, Distance Modulus: 40.933166564649206
# Redshift: 0.29840927363, Distance Modulus: 40.940490924342214
# Redshift: 0.298777444088, Distance Modulus: 40.943513377271906
# Redshift: 0.3, Distance Modulus: 40.95352496360871
# Redshift: 0.300312695802, Distance Modulus: 40.956079540829016
# Redshift: 0.301755029535, Distance Modulus: 40.96783072443256
# Redshift: 0.302, Distance Modulus: 40.96982137873984
# Redshift: 0.30240162108, Distance Modulus: 40.97308173693059
# Redshift: 0.308580866071, Distance Modulus: 41.022742469737196
# Redshift: 0.309, Distance Modulus: 41.02607725772745
# Redshift: 0.309, Distance Modulus: 41.02607725772745
# Redshift: 0.309492645411, Distance Modulus: 41.02999154372026
# Redshift: 0.309547337158, Distance Modulus: 41.03042573558132
# Redshift: 0.312883364158, Distance Modulus: 41.05677578695026
# Redshift: 0.314, Distance Modulus: 41.06553719460801
# Redshift: 0.316429844695, Distance Modulus: 41.08450242139102
# Redshift: 0.32, Distance Modulus: 41.11212301846824
# Redshift: 0.320446988861, Distance Modulus: 41.11556089707342
# Redshift: 0.326396483203, Distance Modulus: 41.16089865771638
# Redshift: 0.329, Distance Modulus: 41.18049662514454
# Redshift: 0.330512448683, Distance Modulus: 41.19181526033326
# Redshift: 0.33063462833, Distance Modulus: 41.192727499776254
# Redshift: 0.331, Distance Modulus: 41.19545362797161
# Redshift: 0.332, Distance Modulus: 41.20290054590632
# Redshift: 0.3373, Distance Modulus: 41.24202326027913
# Redshift: 0.338802609134, Distance Modulus: 41.25301065011861
# Redshift: 0.3396, Distance Modulus: 41.25882288647616
# Redshift: 0.34, Distance Modulus: 41.26173371967619
# Redshift: 0.34, Distance Modulus: 41.26173371967619
# Redshift: 0.3402, Distance Modulus: 41.26318793831199
# Redshift: 0.341, Distance Modulus: 41.268996847442246
# Redshift: 0.342, Distance Modulus: 41.27624012887452
# Redshift: 0.344, Distance Modulus: 41.290667597064434
# Redshift: 0.346, Distance Modulus: 41.30501700338872
# Redshift: 0.348, Distance Modulus: 41.31928921201751
# Redshift: 0.348345020835, Distance Modulus: 41.32174357172556
# Redshift: 0.348583857544, Distance Modulus: 41.32344124551358
# Redshift: 0.352, Distance Modulus: 41.34760542004662
# Redshift: 0.355, Distance Modulus: 41.368646147434745
# Redshift: 0.357, Distance Modulus: 41.38258127592759
# Redshift: 0.357507357032, Distance Modulus: 41.386104727717736
# Redshift: 0.3578, Distance Modulus: 41.388134928323296
# Redshift: 0.360034211989, Distance Modulus: 41.403583792616686
# Redshift: 0.361934308832, Distance Modulus: 41.41665207933712
# Redshift: 0.363, Distance Modulus: 41.42395356219446
# Redshift: 0.366602898789, Distance Modulus: 41.448491099426064
# Redshift: 0.368, Distance Modulus: 41.45794549306284
# Redshift: 0.369, Distance Modulus: 41.464692077401665
# Redshift: 0.3709, Distance Modulus: 41.477463665494795
# Redshift: 0.374, Distance Modulus: 41.498170881436764
# Redshift: 0.378965802039, Distance Modulus: 41.53100930267419
# Redshift: 0.379662293575, Distance Modulus: 41.53558294653345
# Redshift: 0.38, Distance Modulus: 41.53779773750301
# Redshift: 0.380359487336, Distance Modulus: 41.54015335428086
# Redshift: 0.380416514286, Distance Modulus: 41.5405268441732
# Redshift: 0.383, Distance Modulus: 41.55739236273543
# Redshift: 0.387297107465, Distance Modulus: 41.5852105916391
# Redshift: 0.388, Distance Modulus: 41.58973342874781
# Redshift: 0.389288787688, Distance Modulus: 41.59800640349964
# Redshift: 0.391599213441, Distance Modulus: 41.61277355714227
# Redshift: 0.393974478272, Distance Modulus: 41.627870422151105
# Redshift: 0.3965, Distance Modulus: 41.643829192876005
# Redshift: 0.399, Distance Modulus: 41.65953330087895
# Redshift: 0.399601334976, Distance Modulus: 41.66329693455843
# Redshift: 0.4, Distance Modulus: 41.665789177729515
# Redshift: 0.401, Distance Modulus: 41.672030436394785
# Redshift: 0.401, Distance Modulus: 41.672030436394785
# Redshift: 0.401, Distance Modulus: 41.672030436394785
# Redshift: 0.402459619216, Distance Modulus: 41.68111420097635
# Redshift: 0.408319092164, Distance Modulus: 41.71727225202589
# Redshift: 0.41, Distance Modulus: 41.72755526248434
# Redshift: 0.412, Distance Modulus: 41.73973902631681
# Redshift: 0.415, Distance Modulus: 41.75791121327967
# Redshift: 0.416, Distance Modulus: 41.76394127378738
# Redshift: 0.416, Distance Modulus: 41.76394127378738
# Redshift: 0.420926821103, Distance Modulus: 41.79345345839987
# Redshift: 0.421, Distance Modulus: 41.79388936367104
# Redshift: 0.421, Distance Modulus: 41.79388936367104
# Redshift: 0.422, Distance Modulus: 41.79983896721561
# Redshift: 0.423, Distance Modulus: 41.80577537333005
# Redshift: 0.425, Distance Modulus: 41.8176088307347
# Redshift: 0.426, Distance Modulus: 41.82350599973361
# Redshift: 0.429, Distance Modulus: 41.8411199656921
# Redshift: 0.43, Distance Modulus: 41.8469656321722
# Redshift: 0.43, Distance Modulus: 41.8469656321722
# Redshift: 0.43, Distance Modulus: 41.8469656321722
# Redshift: 0.43, Distance Modulus: 41.8469656321722
# Redshift: 0.43, Distance Modulus: 41.8469656321722
# Redshift: 0.43, Distance Modulus: 41.8469656321722
# Redshift: 0.436, Distance Modulus: 41.88177419514347
# Redshift: 0.436, Distance Modulus: 41.88177419514347
# Redshift: 0.44, Distance Modulus: 41.904731145598475
# Redshift: 0.44, Distance Modulus: 41.904731145598475
# Redshift: 0.449, Distance Modulus: 41.95567639599054
# Redshift: 0.45, Distance Modulus: 41.96127767794826
# Redshift: 0.45, Distance Modulus: 41.96127767794826
# Redshift: 0.45, Distance Modulus: 41.96127767794826
# Redshift: 0.451, Distance Modulus: 41.96686728386503
# Redshift: 0.453, Distance Modulus: 41.978011664332456
# Redshift: 0.455, Distance Modulus: 41.98910992773362
# Redshift: 0.46, Distance Modulus: 42.01665634066897
# Redshift: 0.4607, Distance Modulus: 42.02049036614399
# Redshift: 0.4627, Distance Modulus: 42.03141463298259
# Redshift: 0.463, Distance Modulus: 42.03304944379135
# Redshift: 0.465, Distance Modulus: 42.04392280446214
# Redshift: 0.468, Distance Modulus: 42.060150687165404
# Redshift: 0.469, Distance Modulus: 42.065538250738555
# Redshift: 0.47, Distance Modulus: 42.070915022428956
# Redshift: 0.472, Distance Modulus: 42.08163636452124
# Redshift: 0.475, Distance Modulus: 42.09763852122555
# Redshift: 0.477, Distance Modulus: 42.108253884945846
# Redshift: 0.479, Distance Modulus: 42.1188274480929
# Redshift: 0.48, Distance Modulus: 42.124098658176976
# Redshift: 0.49, Distance Modulus: 42.17624947053451
# Redshift: 0.493, Distance Modulus: 42.19169931472929
# Redshift: 0.495, Distance Modulus: 42.201950074731215
# Redshift: 0.495, Distance Modulus: 42.201950074731215
# Redshift: 0.496, Distance Modulus: 42.207060827112485
# Redshift: 0.497, Distance Modulus: 42.21216187754864
# Redshift: 0.497, Distance Modulus: 42.21216187754864
# Redshift: 0.498, Distance Modulus: 42.217253263116696
# Redshift: 0.5, Distance Modulus: 42.22740718687261
# Redshift: 0.5043, Distance Modulus: 42.24910907552609
# Redshift: 0.508, Distance Modulus: 42.26764355493544
# Redshift: 0.51, Distance Modulus: 42.27760923496089
# Redshift: 0.511, Distance Modulus: 42.28257825475793
# Redshift: 0.514, Distance Modulus: 42.29743044296012
# Redshift: 0.519, Distance Modulus: 42.32200320261409
# Redshift: 0.521, Distance Modulus: 42.33176976803647
# Redshift: 0.521, Distance Modulus: 42.33176976803647
# Redshift: 0.522, Distance Modulus: 42.33663977998182
# Redshift: 0.526, Distance Modulus: 42.35603210356673
# Redshift: 0.526, Distance Modulus: 42.35603210356673
# Redshift: 0.528, Distance Modulus: 42.36567607380395
# Redshift: 0.528, Distance Modulus: 42.36567607380395
# Redshift: 0.532, Distance Modulus: 42.38486087765707
# Redshift: 0.539, Distance Modulus: 42.41810846666873
# Redshift: 0.54, Distance Modulus: 42.422824748914046
# Redshift: 0.54, Distance Modulus: 42.422824748914046
# Redshift: 0.543, Distance Modulus: 42.436924179469415
# Redshift: 0.548, Distance Modulus: 42.46026022820065
# Redshift: 0.55, Distance Modulus: 42.469538255443844
# Redshift: 0.55, Distance Modulus: 42.469538255443844
# Redshift: 0.5516, Distance Modulus: 42.47693770528595
# Redshift: 0.552, Distance Modulus: 42.47878439184261
# Redshift: 0.557, Distance Modulus: 42.50176164183291
# Redshift: 0.561, Distance Modulus: 42.52000317445955
# Redshift: 0.562, Distance Modulus: 42.524544295932635
# Redshift: 0.564, Distance Modulus: 42.53360360670766
# Redshift: 0.568, Distance Modulus: 42.55163121670752
# Redshift: 0.57, Distance Modulus: 42.56059992101176
# Redshift: 0.57, Distance Modulus: 42.56059992101176
# Redshift: 0.571, Distance Modulus: 42.56507308558468
# Redshift: 0.579, Distance Modulus: 42.60059314143373
# Redshift: 0.58, Distance Modulus: 42.60500035358791
# Redshift: 0.581, Distance Modulus: 42.609400357506686
# Redshift: 0.581, Distance Modulus: 42.609400357506686
# Redshift: 0.581, Distance Modulus: 42.609400357506686
# Redshift: 0.5817, Distance Modulus: 42.61247608395128
# Redshift: 0.582, Distance Modulus: 42.61379317671349
# Redshift: 0.583, Distance Modulus: 42.61817883461453
# Redshift: 0.591, Distance Modulus: 42.65300906149032
# Redshift: 0.592, Distance Modulus: 42.65733130196012
# Redshift: 0.592, Distance Modulus: 42.65733130196012
# Redshift: 0.599, Distance Modulus: 42.68739408049133
# Redshift: 0.603, Distance Modulus: 42.70442315854887
# Redshift: 0.604, Distance Modulus: 42.70866363635684
# Redshift: 0.61, Distance Modulus: 42.73396706727148
# Redshift: 0.612, Distance Modulus: 42.74234892121324
# Redshift: 0.613, Distance Modulus: 42.746530073157125
# Redshift: 0.613, Distance Modulus: 42.746530073157125
# Redshift: 0.615, Distance Modulus: 42.754872927656756
# Redshift: 0.619, Distance Modulus: 42.771481396881015
# Redshift: 0.62, Distance Modulus: 42.77561753768282
# Redshift: 0.62, Distance Modulus: 42.77561753768282
# Redshift: 0.623, Distance Modulus: 42.7879879285446
# Redshift: 0.6268, Distance Modulus: 42.803575841940216
# Redshift: 0.631, Distance Modulus: 42.82070010896469
# Redshift: 0.631, Distance Modulus: 42.82070010896469
# Redshift: 0.633, Distance Modulus: 42.82881635021379
# Redshift: 0.633, Distance Modulus: 42.82881635021379
# Redshift: 0.64, Distance Modulus: 42.8570317984257
# Redshift: 0.64, Distance Modulus: 42.8570317984257
# Redshift: 0.64, Distance Modulus: 42.8570317984257
# Redshift: 0.643, Distance Modulus: 42.8690340719185
# Redshift: 0.645, Distance Modulus: 42.87700592128559
# Redshift: 0.655, Distance Modulus: 42.91651435570514
# Redshift: 0.656, Distance Modulus: 42.920433445823775
# Redshift: 0.657, Distance Modulus: 42.92434682944731
# Redshift: 0.67, Distance Modulus: 42.9747089219109
# Redshift: 0.671, Distance Modulus: 42.97854411162411
# Redshift: 0.679, Distance Modulus: 43.00903011053087
# Redshift: 0.68, Distance Modulus: 43.01281664853658
# Redshift: 0.687, Distance Modulus: 43.03917399207937
# Redshift: 0.687, Distance Modulus: 43.03917399207937
# Redshift: 0.688, Distance Modulus: 43.042918299572854
# Redshift: 0.691, Distance Modulus: 43.05411999956349
# Redshift: 0.695, Distance Modulus: 43.068983279044
# Redshift: 0.698, Distance Modulus: 43.080076991307344
# Redshift: 0.707, Distance Modulus: 43.11308569108529
# Redshift: 0.71, Distance Modulus: 43.12399899767233
# Redshift: 0.711, Distance Modulus: 43.12762692719309
# Redshift: 0.721, Distance Modulus: 43.16363898125004
# Redshift: 0.73, Distance Modulus: 43.19564164091486
# Redshift: 0.735, Distance Modulus: 43.213257274742006
# Redshift: 0.74, Distance Modulus: 43.23075794437933
# Redshift: 0.741, Distance Modulus: 43.2342444125964
# Redshift: 0.75, Distance Modulus: 43.26542024851676
# Redshift: 0.752, Distance Modulus: 43.27229924347001
# Redshift: 0.756, Distance Modulus: 43.28600448664096
# Redshift: 0.763, Distance Modulus: 43.30982126683285
# Redshift: 0.772, Distance Modulus: 43.340134957399414
# Redshift: 0.78, Distance Modulus: 43.36679538460287
# Redshift: 0.781, Distance Modulus: 43.37010934925219
# Redshift: 0.791, Distance Modulus: 43.4030252762381
# Redshift: 0.799, Distance Modulus: 43.42906958821836
# Redshift: 0.8, Distance Modulus: 43.432307372827346
# Redshift: 0.81, Distance Modulus: 43.46447146469633
# Redshift: 0.811, Distance Modulus: 43.46766669968928
# Redshift: 0.812, Distance Modulus: 43.47085812099337
# Redshift: 0.815, Distance Modulus: 43.480409591984284
# Redshift: 0.816, Distance Modulus: 43.48358584758722
# Redshift: 0.817, Distance Modulus: 43.48675833387148
# Redshift: 0.818, Distance Modulus: 43.4899270596174
# Redshift: 0.821, Distance Modulus: 43.499410760966555
# Redshift: 0.8218, Distance Modulus: 43.501934075234686
# Redshift: 0.83, Distance Modulus: 43.52766160092181
# Redshift: 0.83, Distance Modulus: 43.52766160092181
# Redshift: 0.833, Distance Modulus: 43.537012558614414
# Redshift: 0.839, Distance Modulus: 43.555616843981035
# Redshift: 0.84, Distance Modulus: 43.55870499834434
# Redshift: 0.84, Distance Modulus: 43.55870499834434
# Redshift: 0.85, Distance Modulus: 43.589391690492825
# Redshift: 0.854, Distance Modulus: 43.60156828115477
# Redshift: 0.859, Distance Modulus: 43.61671131197541
# Redshift: 0.86, Distance Modulus: 43.619729633848785
# Redshift: 0.868, Distance Modulus: 43.64375406679757
# Redshift: 0.87, Distance Modulus: 43.64972652008008
# Redshift: 0.874, Distance Modulus: 43.661631453073575
# Redshift: 0.882, Distance Modulus: 43.68528304458012
# Redshift: 0.885, Distance Modulus: 43.69409857285866
# Redshift: 0.905, Distance Modulus: 43.75213503737285
# Redshift: 0.91, Distance Modulus: 43.76644869965158
# Redshift: 0.9271, Distance Modulus: 43.814827737764006
# Redshift: 0.93, Distance Modulus: 43.82294583787725
# Redshift: 0.935, Distance Modulus: 43.83688463869124
# Redshift: 0.936, Distance Modulus: 43.83966365375216
# Redshift: 0.949, Distance Modulus: 43.87552898232546
# Redshift: 0.95, Distance Modulus: 43.87826791351767
# Redshift: 0.95, Distance Modulus: 43.87826791351767
# Redshift: 0.95, Distance Modulus: 43.87826791351767
# Redshift: 0.953, Distance Modulus: 43.886467810357914
# Redshift: 0.96, Distance Modulus: 43.905503061061275
# Redshift: 0.961, Distance Modulus: 43.90821128247045
# Redshift: 0.97, Distance Modulus: 43.932461800103965
# Redshift: 0.97, Distance Modulus: 43.932461800103965
# Redshift: 0.974, Distance Modulus: 43.94316912319787
# Redshift: 0.975, Distance Modulus: 43.94583921977696
# Redshift: 0.978, Distance Modulus: 43.95383343197452
# Redshift: 0.983, Distance Modulus: 43.967103841127084
# Redshift: 1.01, Distance Modulus: 44.03763894063988
# Redshift: 1.01, Distance Modulus: 44.03763894063988
# Redshift: 1.017, Distance Modulus: 44.05562354228847
# Redshift: 1.02, Distance Modulus: 44.063294014314195
# Redshift: 1.02, Distance Modulus: 44.063294014314195
# Redshift: 1.03, Distance Modulus: 44.08870300257412
# Redshift: 1.057, Distance Modulus: 44.15611338628901
# Redshift: 1.092, Distance Modulus: 44.24101496736107
# Redshift: 1.11, Distance Modulus: 44.28363841517271
# Redshift: 1.12, Distance Modulus: 44.30702391277201
# Redshift: 1.124, Distance Modulus: 44.31632035267771
# Redshift: 1.14, Distance Modulus: 44.35318166938147
# Redshift: 1.14, Distance Modulus: 44.35318166938147
# Redshift: 1.188, Distance Modulus: 44.460767181769576
# Redshift: 1.19, Distance Modulus: 44.465155820798884
# Redshift: 1.192, Distance Modulus: 44.46953714494871
# Redshift: 1.215, Distance Modulus: 44.519404186241935
# Redshift: 1.23, Distance Modulus: 44.55142333184006
# Redshift: 1.241, Distance Modulus: 44.57465820313117
# Redshift: 1.265, Distance Modulus: 44.62464899756451
# Redshift: 1.3, Distance Modulus: 44.69588371822639
# Redshift: 1.305, Distance Modulus: 44.70590366907367
# Redshift: 1.307, Distance Modulus: 44.70990092721376
# Redshift: 1.315, Distance Modulus: 44.72582914343204
# Redshift: 1.34, Distance Modulus: 44.77498832297872
# Redshift: 1.35, Distance Modulus: 44.794395878750365
# Redshift: 1.37, Distance Modulus: 44.83278343705069
# Redshift: 1.39, Distance Modulus: 44.870614318760275
# Redshift: 1.414, Distance Modulus: 44.91529833046238

# %% [markdown]
# As the graphs show, the best fine line shows that the parameters are good and the error is minimal (although increasing with redshift, this hared to tell from the graph it is recommended to look at the printed values).
